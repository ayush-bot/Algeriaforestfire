# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
X=6*np.random.rand(100,1) -3
y=0.5 * X**2 + 1.5*X + 2 + np.random.randn(100,1)
#y=0.5x^2 +1.5X + 2 + outliers
plt.plot(X,y,'x',color="r")
plt.xlabel("X axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42 )

# %%
'''from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)'''
# Out:
# 'from sklearn.preprocessing import StandardScaler\nscaler=StandardScaler()\nX_train=scaler.fit_transform(X_train)\nX_test=scaler.transform(X_test)'

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
Y_pred=regression.predict(X_test)

# %%
print(mean_absolute_error(y_test,Y_pred))
print(mean_squared_error(y_test,Y_pred))
# Out:
# 1.4391296164620133
# 3.0616587045427583

# %%
percentage_accuracy=r2_score(y_test,Y_pred)
print(f"{percentage_accuracy*100} % Accuracy")
# Out:
# 66.2718381667525 % Accuracy

# %%
plt.plot(X_train,regression.predict(X_train),color='r')
plt.scatter(X_train,y_train)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2,include_bias=True)

# %%
X_train1=poly.fit_transform(X_train)
X_test1=poly.transform(X_test)
X_train1
# Out:
# array([[ 1.00000000e+00,  2.28715420e+00,  5.23107432e+00],
#        [ 1.00000000e+00, -3.81169901e-01,  1.45290494e-01],
#        [ 1.00000000e+00, -2.95652048e+00,  8.74101332e+00],
#        [ 1.00000000e+00, -2.35789549e+00,  5.55967114e+00],
#        [ 1.00000000e+00,  7.16375844e-01,  5.13194350e-01],
#        [ 1.00000000e+00, -2.35812261e+00,  5.56074225e+00],
#        [ 1.00000000e+00, -1.51105506e+00,  2.28328741e+00],
#        [ 1.00000000e+00, -1.19094047e+00,  1.41833921e+00],
#        [ 1.00000000e+00,  2.42886465e+00,  5.89938348e+00],
#        [ 1.00000000e+00, -1.31486839e+00,  1.72887888e+00],
#        [ 1.00000000e+00,  1.84229660e+00,  3.39405676e+00],
#        [ 1.00000000e+00, -2.91775805e+00,  8.51331205e+00],
#        [ 1.00000000e+00,  1.90242116e+00,  3.61920628e+00],
#        [ 1.00000000e+00,  1.17959880e+00,  1.39145333e+00],
#        [ 1.00000000e+00,  2.79073412e+00,  7.78819695e+00],
#        [ 1.00000000e+00,  8.77038099e-01,  7.69195826e-01],
# ...

# %%
from sklearn.metrics import r2_score
regression.fit(X_train1,y_train)
Y_pred1=regression.predict(X_test1)
score=r2_score(y_test,Y_pred1)
print(score)
# Out:
# 0.9197652848525186

# %%
regression.coef_
# Out:
# array([[0.        , 1.5530438 , 0.46076524]])

# %%
plt.scatter(X_train,regression.predict(X_train1)) # best fit line
plt.scatter(X_train,y_train)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
poly1=PolynomialFeatures(degree=4,include_bias=True)
X_train0=poly1.fit_transform(X_train)
X_test0=poly1.transform(X_test)
from sklearn.metrics import r2_score
regression.fit(X_train0,y_train)
Y_pred0=regression.predict(X_test0)
score1=r2_score(y_test,Y_pred0)
print(score1)
plt.scatter(X_train,regression.predict(X_train0)) # best fit line
plt.scatter(X_train,y_train)
# Out:
# 0.8947381912756317

# %%
#prediction of new data set
X_new= np.linspace(-3,3,200).reshape(200,1)
X_new_poly=poly.transform(X_new)
X_new_poly
# Out:
# array([[ 1.00000000e+00, -3.00000000e+00,  9.00000000e+00],
#        [ 1.00000000e+00, -2.96984925e+00,  8.82000455e+00],
#        [ 1.00000000e+00, -2.93969849e+00,  8.64182723e+00],
#        [ 1.00000000e+00, -2.90954774e+00,  8.46546804e+00],
#        [ 1.00000000e+00, -2.87939698e+00,  8.29092700e+00],
#        [ 1.00000000e+00, -2.84924623e+00,  8.11820409e+00],
#        [ 1.00000000e+00, -2.81909548e+00,  7.94729931e+00],
#        [ 1.00000000e+00, -2.78894472e+00,  7.77821267e+00],
#        [ 1.00000000e+00, -2.75879397e+00,  7.61094417e+00],
#        [ 1.00000000e+00, -2.72864322e+00,  7.44549380e+00],
#        [ 1.00000000e+00, -2.69849246e+00,  7.28186157e+00],
#        [ 1.00000000e+00, -2.66834171e+00,  7.12004747e+00],
#        [ 1.00000000e+00, -2.63819095e+00,  6.96005151e+00],
#        [ 1.00000000e+00, -2.60804020e+00,  6.80187369e+00],
#        [ 1.00000000e+00, -2.57788945e+00,  6.64551400e+00],
#        [ 1.00000000e+00, -2.54773869e+00,  6.49097245e+00],
# ...

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
y_new =regression.predict(X_new_poly)

plt.plot(X_new, y_new, "r-", linewidth=2, label=" New Predictions")
plt.plot(X_train, y_train, "b.",label='Training points')
plt.plot(X_test, y_test, "g.",label='Testing points')
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[156], line 3
#       1 from sklearn.linear_model import LinearRegression
#       2 regression=LinearRegression()
# ----> 3 y_new =regression.predict(X_new_poly)
#       5 plt.plot(X_new, y_new, "r-", linewidth=2, label=" New Predictions")
#       6 plt.plot(X_train, y_train, "b.",label='Training points')
#
# File c:\Users\Administrator\Downloads\Udemy\python\venv\Lib\site-packages\sklearn\linear_model\_base.py:298, in LinearModel.predict(self, X)
#     284 def predict(self, X):
#     285     """
#     286     Predict using the linear model.
#     287
#    (...)    296         Returns predicted values.
#     297     """
# --> 298     return self._decision_function(X)
#
# File c:\Users\Administrator\Downloads\Udemy\python\venv\Lib\site-packages\sklearn\linear_model\_base.py:275, in LinearModel._decision_function(self, X)
# ...

# %%
from sklearn.pipeline import Pipeline

# %%
def poly_regression(degree):
    X_new = np.linspace(-3, 3, 200).reshape(200, 1)
    
    poly_features=PolynomialFeatures(degree=degree,include_bias=True)
    lin_reg=LinearRegression()
    poly_regression=Pipeline([
        ("poly_feature",poly_features),
        ("lin_re",lin_reg)
    ])
    poly_regression.fit(X_train,y_train) ## ploynomial and fit of linear reression
    y_pred_new=poly_regression.predict(X_new)
    #plotting prediction line
    plt.plot(X_new, y_pred_new,'r', label="Degree " + str(degree) ,linewidth=2)
    plt.plot(X_train, y_train, "b.", linewidth=3,label="TRAINING POINTS")
    plt.plot(X_test, y_test, "g.", linewidth=3,label="TEST DATAPOINTS")
    plt.legend(loc="upper left")
    plt.xlabel("X")
    plt.ylabel("y") 
    plt.axis([-4,4, 0, 10])
    plt.show()

# %%
poly_regression(5)
